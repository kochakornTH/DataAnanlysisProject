# %% [markdown]
# <a href="https://colab.research.google.com/github/kochakornTH/202512_01_Airline/blob/main/202512_01_Airline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pd = pd.read_csv('flight.csv')

# %%
pd.head().T
# Out:
#                               0        1        2         3        4
# miles                       792     3163     1832       925      967
# passengers                  172      214      212       213      217
# delay                         0        0        0         0        0
# inflight_meal                No       No       No        No      Yes
# inflight_entertainment      Yes      Yes      Yes       Yes      Yes
# inflight_wifi               Yes      Yes       No       Yes      Yes
# day_of_week              Sunday   Sunday   Friday  Saturday   Monday
# redeye                      Yes       No       No        No       No
# weekend                     Yes      Yes      Yes       Yes       No
# coach_price              338.82  472.655   351.96   387.835  374.735
# firstclass_price        1571.02   1663.7  1429.86   1558.76  1245.58
# hours                         1        6        3         2        2
